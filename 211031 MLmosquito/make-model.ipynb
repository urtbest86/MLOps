# %%
# %matplotlib inline
import numpy as np
import os

# %%
import azureml
from azureml.core import Workspace

# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.34.0

# %% [markdown]
# # Connect Workspace

# %%
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Workspace name: mlrgeastus
# Azure region: eastus
# Subscription id: 932c3e14-d0cf-4e41-9998-bdebb9bfa1cf
# Resource group: mlrg

# %% [markdown]
# # Create experiment

# %%
from azureml.core import Experiment
experiment_name = 'myExp'

exp = Experiment(workspace=ws, name=experiment_name)

# %%
script_folder = './'
os.makedirs(script_folder, exist_ok=True)

with open(os.path.join(script_folder, 'myModel.py'), 'r') as f:
    print(f.read())
# Out:
# import pandas as pd
# import numpy as np
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
#
#
#
# DATA_PATH="https://raw.githubusercontent.com/urtbest86/MLOps/master/result_train_dataset2.csv"
# df = pd.read_csv(DATA_PATH)
#
# DATA_PATH="https://raw.githubusercontent.com/urtbest86/MLOps/master/result_test_dataset2.csv"
# test = pd.read_csv(DATA_PATH)
#
# train=df.sample(frac=0.8)
# val=df.sample(frac=0.2)
#
# mean = train.mean(axis=0)
# train -= mean
# std = train.std(axis=0)
# train /= std
#
# test -= mean
# test /= std
#
# val-=mean
# val/=std
#
# train_data_set = train.values
# x_train = train_data_set[:, 2:-1].astype(float)
# y_train = train_data_set[:, -1].astype(float)
#
# test_data_set = test.values
# x_test = test_data_set[:, 2:-1].astype(float)
# y_test = test_data_set[:, -1].astype(float)
#
# val_data_set = val.values
# x_val = val_data_set[:, 2:-1].astype(float)
# y_val = val_data_set[:, -1].astype(float)
#
#
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
#
# model = Sequential()
# model.add(Dense(1024, input_dim = 4, activation='relu'))
# model.add(Dense(500,activation='relu'))
# model.add(Dense(300,activation='relu'))
# model.add(Dense(200,activation='relu'))
# model.add(Dense(1))
#
#
# rgs=model.compile(loss='mse', optimizer='adam',metrics=['mae'])
#
# eph_size=150
# hist=model.fit(x_train, y_train, epochs=eph_size, batch_size=4,validation_data=(x_val,y_val))
#
#
# laoss_nd_metrics = model.evaluate(x_test, y_test, batch_size=32)
#
#
#
# from azureml.core.run import Run
# # start an Azure ML run
# run = Run.get_context()
#
# # log a single value
# run.log("Final test loss(mse)", laoss_nd_metrics[0])
# print('Test loss(mse):', laoss_nd_metrics[0])
#
# run.log('Final test loss(mae)', laoss_nd_metrics[1])
# print('Test loss(mae):', laoss_nd_metrics[1])
#
#
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(6, 3))
# plt.title('Mosquito with Keras MLP ({} epochs)'.format(eph_size), fontsize=14)
# plt.plot(hist.history['loss'], 'b-', label='loss', lw=4, alpha=0.5)
# plt.plot(hist.history['val_loss'], 'r--', label='val_loss', lw=4, alpha=0.5)
# plt.legend(fontsize=12)
# plt.grid(True)
# plt.show()
# run.log_image('loss VS val_loss', plot=plt)
#
#
# import joblib
#
# os.makedirs('outputs', exist_ok=True)
# # note file saved in the outputs folder is automatically uploaded into experiment record
# joblib.dump(value=rgs, filename='outputs/Youjin_test_model.pkl')
#
# '''import matplotlib.pyplot as plt
#
# plt.plot(model.predict(x_test),label='predict value')
# plt.plot(y_test, label='real value')
# plt.plot(model.predict(x_test))
# plt.legend()
# plt.show()
#
#
# from azureml.core import Run
#
# run = Run.get_context()
#
# score = model.evaluate(x_test, y_test, verbose=0)
#
# run.log_image('Accuracy vs Loss', plot=plt)'''

# %% [markdown]
# # Attach existing compute resource

# %%
'''from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
import os

compute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "test-cluster")

if compute_name in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
else:
    print("creating new compute target...")'''
# Out:
# 'from azureml.core.compute import AmlCompute\nfrom azureml.core.compute import ComputeTarget\nimport os\n\ncompute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "test-cluster")\n\nif compute_name in ws.compute_targets:\n    compute_target = ws.compute_targets[compute_name]\n    if compute_target and type(compute_target) is AmlCompute:\n        print("found compute target: " + compute_name)\nelse:\n    print("creating new compute target...")'

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
import os

# choose a name for your cluster
compute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "cpu-cluster")
compute_min_nodes = os.environ.get("AML_COMPUTE_CLUSTER_MIN_NODES", 0)
compute_max_nodes = os.environ.get("AML_COMPUTE_CLUSTER_MAX_NODES", 4)

# This example uses CPU VM. For using GPU VM, set SKU to STANDARD_NC6
vm_size = os.environ.get("AML_COMPUTE_CLUSTER_SKU", "STANDARD_D11_V2")


if compute_name in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
else:
    print("creating new compute target...")
    provisioning_config = AmlCompute.provisioning_configuration(vm_size = vm_size,
                                                                min_nodes = compute_min_nodes, 
                                                                max_nodes = compute_max_nodes)

    # create the cluster
    compute_target = ComputeTarget.create(ws, compute_name, provisioning_config)
    
    # can poll for a minimum number of nodes and for a specific timeout. 
    # if no min node count is provided it will use the scale settings for the cluster
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
    
     # For a more detailed view of current AmlCompute status, use get_status()
    print(compute_target.get_status().serialize())
# Out:
# creating new compute target...
# InProgress....
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Resizing', 'allocationStateTransitionTime': '2021-10-31T14:50:57.221000+00:00', 'errors': None, 'creationTime': '2021-10-31T14:50:56.834548+00:00', 'modifiedTime': '2021-10-31T14:51:12.407329+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT1800S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D11_V2'}

# %%
# %%writefile conda_dependencies.yml
#
# channels:
# - conda-forge
# dependencies:
# - python=3.6.2
#
# - pip:
#   - h5py<=2.10.0
#   - azureml-defaults
#   - tensorflow-gpu==2.0.0
#   - keras<=2.3.1
#   - matplotlib
#   - pandas
#   - scikit-learn
# Out:
# Overwriting conda_dependencies.yml

# %%
from azureml.core import Environment

env = Environment.from_conda_specification(name = 'keras-2.3.1', file_path = './conda_dependencies.yml')

'''# Specify a GPU base image
env.docker.enabled = True
env.docker.base_image = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu18.04'''

env.register(workspace = ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "keras-2.3.1",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "h5py<=2.10.0",
#                         "azureml-defaults",
#                         "tensorflow-gpu==2.0.0",
#                         "keras<=2.3.1",
#                         "matplotlib",
#                         "pandas",
#                         "scikit-learn"
#                     ]
#                 }
#             ],
#             "name": "azureml_a8a0845f249cc373e9e7168f4f641be5"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %% [markdown]
# # 학습 실행 구성 및 제출
# ## ScriptRunConfig 만들기

# %%
from azureml.core import ScriptRunConfig

args = ['--data-folder', 
        '--batch-size', 4,
        '--first-layer-neurons', 1024,
        '--second-layer-neurons', 500,
        '--third-layer-neurons', 300,
        '--forth-layer-neurons', 200,
        '--learning-rate', 0.001]

src = ScriptRunConfig(source_directory=script_folder,
                      script='myModel.py',
                      arguments=args,
                      compute_target=compute_name,
                      environment=env)

# %%
run = exp.submit(src)

# %%
from azureml.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
run
# Out:
# Run(Experiment: myExp,
# Id: myExp_1635691878_4428a645,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: myExp_1635691878_4428a645
# Web View: https://ml.azure.com/runs/myExp_1635691878_4428a645?wsid=/subscriptions/932c3e14-d0cf-4e41-9998-bdebb9bfa1cf/resourcegroups/mlrg/workspaces/mlrgeastus&tid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/10/31 14:51:33 Downloading source code...
# 2021/10/31 14:51:34 Finished downloading source code
# 2021/10/31 14:51:34 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/10/31 14:51:34 Successfully set up Docker network: acb_default_network
# 2021/10/31 14:51:34 Setting up Docker configuration...
# 2021/10/31 14:51:35 Successfully set up Docker configuration
# 2021/10/31 14:51:35 Logging in to registry: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io
# 2021/10/31 14:51:36 Successfully logged into 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io
# 2021/10/31 14:51:36 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/31 14:51:36 Scanning for dependencies...
# 2021/10/31 14:51:36 Successfully scanned dependencies
# 2021/10/31 14:51:36 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# feac53061382: Pull complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# Digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#  ---> 82e13edbc8db
# Step 2/19 : USER root
#  ---> Running in 410c1105ec7f
# Removing intermediate container 410c1105ec7f
#  ---> b0563b012a8f
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in 9a9a39674607
# Removing intermediate container 9a9a39674607
#  ---> a9005798b475
# Step 4/19 : WORKDIR /
#  ---> Running in ba768543b8de
# Removing intermediate container ba768543b8de
#  ---> 4e597ff4d8ed
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 7fe3296bfff2
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in e1671630f357
# Removing intermediate container e1671630f357
#  ---> 1fac26dc6ce1
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 0260809c9a3c
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 9a1198665307
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# xz-5.2.5             | 343 KB    |            |   0%
# xz-5.2.5             | 343 KB    | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
#
# sqlite-3.13.0        | 4.9 MB    |            |   0%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# ncurses-5.9          | 1.1 MB    |            |   0%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
#
# readline-6.2         | 713 KB    |            |   0%
# readline-6.2         | 713 KB    | ########## | 100%
# readline-6.2         | 713 KB    | ########## | 100%
#
# libgomp-11.2.0       | 427 KB    |            |   0%
# libgomp-11.2.0       | 427 KB    | ########## | 100%
#
# python-3.6.2         | 19.0 MB   |            |   0%
# python-3.6.2         | 19.0 MB   | #####4     |  55%
# python-3.6.2         | 19.0 MB   | ########## | 100%
# python-3.6.2         | 19.0 MB   | ########## | 100%
#
# setuptools-58.0.4    | 966 KB    |            |   0%
# setuptools-58.0.4    | 966 KB    | ########## | 100%
# setuptools-58.0.4    | 966 KB    | ########## | 100%
#
# pip-21.3.1           | 1.2 MB    |            |   0%
# pip-21.3.1           | 1.2 MB    | ########## | 100%
# pip-21.3.1           | 1.2 MB    | ########## | 100%
#
# ca-certificates-2021 | 139 KB    |            |   0%
# ca-certificates-2021 | 139 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# tk-8.5.19            | 1.9 MB    |            |   0%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
#
# libzlib-1.2.11       | 59 KB     |            |   0%
# libzlib-1.2.11       | 59 KB     | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# wheel-0.37.0         | 31 KB     |            |   0%
# wheel-0.37.0         | 31 KB     | ########## | 100%
#
# libgcc-ng-11.2.0     | 887 KB    |            |   0%
# libgcc-ng-11.2.0     | 887 KB    | ########## | 100%
# libgcc-ng-11.2.0     | 887 KB    | ########## | 100%
#
# zlib-1.2.11          | 86 KB     |            |   0%
# zlib-1.2.11          | 86 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.o0p1tch1.requirements.txt']
# Pip subprocess output:
# Collecting h5py<=2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.35.0-py3-none-any.whl (3.1 kB)
# Collecting tensorflow-gpu==2.0.0
#   Downloading tensorflow_gpu-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (380.8 MB)
# Collecting keras<=2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading tensorboard-2.0.2-py3-none-any.whl (3.8 MB)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.13.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (78 kB)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.41.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting protobuf>=3.6.1
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting google-pasta>=0.1.6
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting six>=1.10.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting numpy<2.0,>=1.16.0
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Requirement already satisfied: wheel>=0.26 in /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/python3.6/site-packages (from tensorflow-gpu==2.0.0->-r /azureml-environment-setup/condaenv.o0p1tch1.requirements.txt (line 3)) (0.37.0)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.2-py3-none-any.whl (38 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting azureml-core~=1.35.0
#   Downloading azureml_core-1.35.0.post1-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.35.0
#   Downloading azureml_dataset_runtime-1.35.0-py3-none-any.whl (3.5 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.o0p1tch1.requirements.txt (line 2)) (58.0.4)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting scipy>=0.14
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.4.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-3.0.4-py3-none-any.whl (96 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting ruamel.yaml<=0.17.16,>=0.17.10
#   Downloading ruamel.yaml-0.17.16-py3-none-any.whl (109 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.2.0-py2.py3-none-any.whl (412 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.24.0a,>=2.23.0a
#   Downloading azureml_dataprep-2.23.2-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex~=1.21.0dev0
#   Downloading azureml_dataprep_rslex-1.21.2-cp36-cp36m-manylinux2010_x86_64.whl (13.0 MB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.2.1-py2.py3-none-any.whl (95 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Building wheels for collected packages: gast, json-logging-py, termcolor, wrapt, fusepy, contextvars
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=480afa16b6514c135971dc8c1e72c855aa744941e47dda7659d98fc3c6c0b2c0
#   Stored in directory: /root/.cache/pip/wheels/19/a7/b9/0740c7a3a7d1d348f04823339274b90de25fbcd217b2ee1fbe
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=97521a27154630ef8eecab98d1af9f5c0e39d5f653b2524d37e626f721ce7fc9
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=c01ab5c7aa0077db318ee0069907e1ea6693c9a1b383a57a681e6522d4260bde
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69938 sha256=2d5c2529dc01221c7ac16a4fe89919022e3a17fe3cc5b927195a5645139ee2c1
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=859c76501a5b2a0dc47c4a7e1c1ddc2c758e4fae5b1c123e27240150b0bded69
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=69380a064f47f26bd5323250104bdf45df5c52984f1d106a500095626983ed2a
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built gast json-logging-py termcolor wrapt fusepy contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, certifi, requests, typing-extensions, six, pyasn1, portalocker, oauthlib, msal, zipp, rsa, requests-oauthlib, python-dateutil, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, numpy, msrest, MarkupSafe, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, werkzeug, websocket-client, ruamel.yaml.clib, pytz, pyopenssl, pyarrow, opencensus-context, msrestazure, Jinja2, jeepney, itsdangerous, google-api-core, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, markdown, jsonpickle, jmespath, inference-schema, h5py, gunicorn, grpcio, google-auth-oauthlib, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, absl-py, threadpoolctl, termcolor, tensorflow-estimator, tensorboard, scipy, pyyaml, pyparsing, pillow, opt-einsum, opencensus-ext-azure, kiwisolver, keras-preprocessing, keras-applications, json-logging-py, joblib, google-pasta, gast, cycler, configparser, azureml-inference-server-http, azureml-core, astor, tensorflow-gpu, scikit-learn, pandas, matplotlib, keras, azureml-defaults
# Successfully installed Jinja2-3.0.2 MarkupSafe-2.0.1 PyJWT-2.3.0 SecretStorage-3.3.1 absl-py-0.15.0 adal-1.2.7 applicationinsights-0.11.10 astor-0.8.1 azure-common-1.1.27 azure-core-1.19.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.35.0.post1 azureml-dataprep-2.23.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.21.2 azureml-dataset-runtime-1.35.0 azureml-defaults-1.35.0 azureml-inference-server-http-0.3.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.4 certifi-2021.10.8 cffi-1.15.0 charset-normalizer-2.0.7 click-8.0.3 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 cycler-0.11.0 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 gast-0.2.2 google-api-core-2.2.1 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 googleapis-common-protos-1.53.0 grpcio-1.41.1 gunicorn-20.1.0 h5py-2.10.0 idna-3.3 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 joblib-1.1.0 json-logging-py-0.2 jsonpickle-2.0.0 keras-2.3.1 keras-applications-1.0.8 keras-preprocessing-1.1.2 kiwisolver-1.3.1 markdown-3.3.4 matplotlib-3.3.4 msal-1.16.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.1 opencensus-0.8.0 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 opt-einsum-3.3.0 pandas-1.1.5 pathspec-0.9.0 pillow-8.4.0 portalocker-1.7.1 protobuf-3.19.1 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-3.0.4 python-dateutil-2.8.2 pytz-2021.3 pyyaml-6.0 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.16 ruamel.yaml.clib-0.2.6 scikit-learn-0.24.2 scipy-1.5.4 six-1.16.0 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.0.0 termcolor-1.1.0 threadpoolctl-3.0.0 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.6.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 9a1198665307
#  ---> 2d448960ea90
# Step 9/19 : ENV PATH /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/bin:$PATH
#  ---> Running in 7396aa077e7e
# Removing intermediate container 7396aa077e7e
#  ---> 8b3c0ff2e0c7
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 2ac0134128d3
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 4df4120fea05
# Copying environment context
# Removing intermediate container 4df4120fea05
#  ---> 8d658757ab3a
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 31a7b3466378
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5
#  ---> Running in d306c8a7348f
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container d306c8a7348f
#  ---> 55d9a2a5e9d6
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5
#  ---> Running in e3f8a001911c
# Removing intermediate container e3f8a001911c
#  ---> 75cf3a74cd9d
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib:$LD_LIBRARY_PATH
#  ---> Running in 95db452bcf56
# Removing intermediate container 95db452bcf56
#  ---> d7d03df7b5b7
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 5cf8f9bd577a
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 5b13786de9c0
# Removing intermediate container 5b13786de9c0
#  ---> fcbbf758398a
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in e7d89f41d883
# Removing intermediate container e7d89f41d883
#  ---> c2e5130cc108
# Step 19/19 : CMD ["bash"]
#  ---> Running in fae2285518fb
# Removing intermediate container fae2285518fb
#  ---> fa962ae4b467
# Successfully built fa962ae4b467
# Successfully tagged 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:latest
# Successfully tagged 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:1
# 2021/10/31 14:54:43 Successfully executed container: acb_step_0
# 2021/10/31 14:54:43 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/31 14:54:43 Pushing image: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:1, attempt 1
# The push refers to repository [0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7]
# fa02fc1bdea0: Preparing
# aa40202a4be5: Preparing
# f69e4b0ba443: Preparing
# c7c9f77619ec: Preparing
# 5cd6c9b7d43e: Preparing
# fdb4f2630544: Preparing
# eb24fa6ba3a0: Preparing
# d9ce900300ab: Preparing
# a2599f2e78e8: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# fdb4f2630544: Waiting
# eb24fa6ba3a0: Waiting
# d9ce900300ab: Waiting
# a2599f2e78e8: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# c7c9f77619ec: Pushed
# f69e4b0ba443: Pushed
# fa02fc1bdea0: Pushed
# aa40202a4be5: Pushed
# fdb4f2630544: Pushed
# d9ce900300ab: Pushed
# eb24fa6ba3a0: Pushed
# a2599f2e78e8: Pushed
# 9398792c8299: Pushed
# 93c9ec44fed0: Pushed
# 5e9c7e64af11: Pushed
# e0ae5bb40eae: Pushed
# 94c0f7816c07: Pushed
# accea658c5be: Pushed
# 20e11b7f408c: Pushed
# 21639b09744f: Pushed
# c96f19f3c075: Pushed
# 5cd6c9b7d43e: Pushed
# 1: digest: sha256:18ce385a05adcc7ca5c2383b5770dfd51e94e50ee4144ab645f77a56c85f6bac size: 4099
# 2021/10/31 14:56:35 Successfully pushed image: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:1
# 2021/10/31 14:56:35 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/31 14:56:35 Pushing image: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:latest, attempt 1
# The push refers to repository [0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7]
# fa02fc1bdea0: Preparing
# aa40202a4be5: Preparing
# f69e4b0ba443: Preparing
# c7c9f77619ec: Preparing
# 5cd6c9b7d43e: Preparing
# fdb4f2630544: Preparing
# eb24fa6ba3a0: Preparing
# d9ce900300ab: Preparing
# a2599f2e78e8: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# fdb4f2630544: Waiting
# eb24fa6ba3a0: Waiting
# d9ce900300ab: Waiting
# a2599f2e78e8: Waiting
# 94c0f7816c07: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# fa02fc1bdea0: Layer already exists
# 5cd6c9b7d43e: Layer already exists
# f69e4b0ba443: Layer already exists
# aa40202a4be5: Layer already exists
# a2599f2e78e8: Layer already exists
# fdb4f2630544: Layer already exists
# 93c9ec44fed0: Layer already exists
# 9398792c8299: Layer already exists
# e0ae5bb40eae: Layer already exists
# 5e9c7e64af11: Layer already exists
# c7c9f77619ec: Layer already exists
# 20e11b7f408c: Layer already exists
# accea658c5be: Layer already exists
# 94c0f7816c07: Layer already exists
# c96f19f3c075: Layer already exists
# 21639b09744f: Layer already exists
# d9ce900300ab: Layer already exists
# eb24fa6ba3a0: Layer already exists
# latest: digest: sha256:18ce385a05adcc7ca5c2383b5770dfd51e94e50ee4144ab645f77a56c85f6bac size: 4099
# 2021/10/31 14:56:37 Successfully pushed image: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:latest
# 2021/10/31 14:56:37 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 187.179287)
# 2021/10/31 14:56:37 Populating digests for step ID: acb_step_0...
# 2021/10/31 14:56:39 Successfully populated digests for step ID: acb_step_0
# 2021/10/31 14:56:39 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 112.312279)
# 2021/10/31 14:56:39 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.220599)
# 2021/10/31 14:56:39 The following dependencies were found:
# 2021/10/31 14:56:39
# - image:
#     registry: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io
#     repository: azureml/azureml_dded69baa6f866c564c25bc60667a4a7
#     tag: latest
#     digest: sha256:18ce385a05adcc7ca5c2383b5770dfd51e94e50ee4144ab645f77a56c85f6bac
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
# - image:
#     registry: 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io
#     repository: azureml/azureml_dded69baa6f866c564c25bc60667a4a7
#     tag: "1"
#     digest: sha256:18ce385a05adcc7ca5c2383b5770dfd51e94e50ee4144ab645f77a56c85f6bac
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
#
#
# Run ID: ca1 was successful after 5m7s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt
# ========================================================================================================================
#
# 2021-10-31T15:01:47Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635691878_4428a645/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635691878_4428a645/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=92214 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635691878_4428a645/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-31T15:01:48Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635691878_4428a645/mounts/workspaceblobstore
# 2021-10-31T15:01:48Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-31T15:01:48Z Starting output-watcher...
# 2021-10-31T15:01:48Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-31T15:01:48Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-10-31T15:01:48Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_dded69baa6f866c564c25bc60667a4a7
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 895644857fa2: Pulling fs layer
# ac60b3a12db0: Pulling fs layer
# 620318f0d971: Pulling fs layer
# bb61db071304: Pulling fs layer
# d5fade19af4a: Pulling fs layer
# 08ac2cd8d847: Pulling fs layer
# 205fc2fec612: Pulling fs layer
# 16687cd6ada7: Pulling fs layer
# f504f346ed75: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# 895644857fa2: Waiting
# ac60b3a12db0: Waiting
# 620318f0d971: Waiting
# bb61db071304: Waiting
# d5fade19af4a: Waiting
# 08ac2cd8d847: Waiting
# 205fc2fec612: Waiting
# 16687cd6ada7: Waiting
# f504f346ed75: Waiting
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 895644857fa2: Verifying Checksum
# 895644857fa2: Download complete
# ac60b3a12db0: Verifying Checksum
# ac60b3a12db0: Download complete
# 620318f0d971: Verifying Checksum
# 620318f0d971: Download complete
# bb61db071304: Verifying Checksum
# bb61db071304: Download complete
# 08ac2cd8d847: Verifying Checksum
# 08ac2cd8d847: Download complete
# 205fc2fec612: Verifying Checksum
# 205fc2fec612: Download complete
# f504f346ed75: Verifying Checksum
# f504f346ed75: Download complete
# 16687cd6ada7: Verifying Checksum
# 16687cd6ada7: Download complete
# feac53061382: Pull complete
# d5fade19af4a: Verifying Checksum
# d5fade19af4a: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# 895644857fa2: Pull complete
# ac60b3a12db0: Pull complete
# 620318f0d971: Pull complete
# bb61db071304: Pull complete
# d5fade19af4a: Pull complete
# 08ac2cd8d847: Pull complete
# 205fc2fec612: Pull complete
# 16687cd6ada7: Pull complete
# f504f346ed75: Pull complete
# Digest: sha256:18ce385a05adcc7ca5c2383b5770dfd51e94e50ee4144ab645f77a56c85f6bac
# Status: Downloaded newer image for 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:latest
# 0bc3a186164e4d5b93a43d2334d6fb27.azurecr.io/azureml/azureml_dded69baa6f866c564c25bc60667a4a7:latest
# 2021-10-31T15:02:30Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-31T15:02:30Z Check if container myexp_1635691878_4428a645 already exist exited with 0,
#
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/10/31 15:02:42 Got JobInfoJson from env
# 2021/10/31 15:02:42 Starting App Insight Logger for task:  runTaskLet
# 2021/10/31 15:02:42 Version: 3.0.01755.0003 Branch: .SourceBranch Commit: 66828d8
# 2021/10/31 15:02:42 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/10/31 15:02:42 Send process info logs to master server succeeded
# 2021/10/31 15:02:42 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/10/31 15:02:42 Send process info logs to master server succeeded
# [2021-10-31T15:02:42.508635] Entering context manager injector.
# [2021-10-31T15:02:43.095185] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['myModel.py', '--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001'])
# Script type = None
# [2021-10-31T15:02:43.099925] Entering Run History Context Manager.
# [2021-10-31T15:02:43.875042] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635691878_4428a645/wd/azureml/myExp_1635691878_4428a645
# [2021-10-31T15:02:43.875097] Preparing to call script [myModel.py] with arguments:['--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001']
# [2021-10-31T15:02:43.875122] After variable expansion, calling script [myModel.py] with arguments:['--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001']
#
# 2021-10-31 15:02:45.851025: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib:
# 2021-10-31 15:02:45.851059: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-31 15:02:45.851086: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (dd20b2648a914cd0a69591dd6fb8e6ac000000): /proc/driver/nvidia/version does not exist
# 2021-10-31 15:02:45.851288: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-10-31 15:02:45.857840: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2095175000 Hz
# 2021-10-31 15:02:45.858030: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5daf160 executing computations on platform Host. Devices:
# 2021-10-31 15:02:45.858059: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on
# 596/809 [=====================>........] - ETA: 0s - loss: 0.2164 - mae: 0.2877
# 636/809 [======================>.......] - ETA: 0s - loss: 0.2320 - mae: 0.2928
# 680/809 [========================>.....] - ETA: 0s - loss: 0.2388 - mae: 0.2979
# 716/809 [=========================>....] - ETA: 0s - loss: 0.2362 - mae: 0.2999
# 756/809 [===========================>..] - ETA: 0s - loss: 0.2356 - mae: 0.2978
# 796/809 [============================>.] - ETA: 0s - loss: 0.2333 - mae: 0.2975
# 809/809 [==============================] - 1s 1ms/sample - loss: 0.2310 - mae: 0.2962 - val_loss: 0.4348 - val_mae: 0.4196
# Epoch 148/150
#
#   4/809 [..............................] - ETA: 1s - loss: 0.0413 - mae: 0.1732
#  48/809 [>.............................] - ETA: 0s - loss: 0.1435 - mae: 0.2545
#  92/809 [==>...........................] - ETA: 0s - loss: 0.1621 - mae: 0.2555
# 136/809 [====>.........................] - ETA: 0s - loss: 0.1965 - mae: 0.2771
#
# Streaming azureml-logs/75_job_post-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# [2021-10-31T15:05:47.242740] Entering job release
# [2021-10-31T15:05:48.322682] Starting job release
# [2021-10-31T15:05:48.323301] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 629
# [2021-10-31T15:05:48.323778] job release stage : upload_datastore starting...
# [2021-10-31T15:05:48.326755] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-31T15:05:48.327075] Entering context manager injector.
# [2021-10-31T15:05:48.333207] job release stage : execute_job_release starting...
# [2021-10-31T15:05:48.333861] job release stage : copy_batchai_cached_logs starting...
# [2021-10-31T15:05:48.334792] job release stage : copy_batchai_cached_logs completed...
# [2021-10-31T15:05:48.337211] job release stage : upload_datastore completed...
# [2021-10-31T15:05:48.419917] job release stage : send_run_telemetry starting...
# [2021-10-31T15:05:48.441457] get vm size and vm region successfully.
# [2021-10-31T15:05:48.450125] get compute meta data successfully.
# [2021-10-31T15:05:48.582858] job release stage : execute_job_release completed...
# [2021-10-31T15:05:48.661720] post artifact meta request successfully.
# [2021-10-31T15:05:48.699865] upload compute record artifact successfully.
# [2021-10-31T15:05:48.700051] job release stage : send_run_telemetry completed...
# [2021-10-31T15:05:48.700608] Job release is complete
#
# Execution Summary
# =================
# RunId: myExp_1635691878_4428a645
# Web View: https://ml.azure.com/runs/myExp_1635691878_4428a645?wsid=/subscriptions/932c3e14-d0cf-4e41-9998-bdebb9bfa1cf/resourcegroups/mlrg/workspaces/mlrgeastus&tid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65
# {'runId': 'myExp_1635691878_4428a645',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2021-10-31T15:01:46.500343Z',
#  'endTimeUtc': '2021-10-31T15:05:59.384305Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '07d5ffc9-aeda-4775-8a30-601049b46c73',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'myModel.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-folder',
#    '--batch-size',
#    '4',
#    '--first-layer-neurons',
#    '1024',
#    '--second-layer-neurons',
#    '500',
#    '--third-layer-neurons',
#    '300',
#    '--forth-layer-neurons',
#    '200',
#    '--learning-rate',
#    '0.001'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'keras-2.3.1',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['h5py<=2.10.0',
#         'azureml-defaults',
#         'tensorflow-gpu==2.0.0',
#         'keras<=2.3.1',
#         'matplotlib',
#         'pandas',
#         'scikit-learn']}],
#      'name': 'azureml_a8a0845f249cc373e9e7168f4f641be5'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True}},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=%2BrZLR6ubI31S6ROWbEn7TlsWFch8BEmzoJ3njTYk%2FK4%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/55_azureml-execution-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt?sv=2019-07-07&sr=b&sig=v%2FEoAkASzE9vaBCNvLooQVwtJRleMfa6KUF8cs7Qyh8%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/65_job_prep-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt?sv=2019-07-07&sr=b&sig=LzqhTgbnUxSdRMgnzew8DfdeqSkrIIAiCa%2FmdUmealw%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=r9iNa3eTywI%2FmTh1mLnN2o%2BlmrwJa3BwkJXsjOnBpA0%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/75_job_post-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt?sv=2019-07-07&sr=b&sig=jgVhqsXcwhpkA5hMxzgopW8r29tauBxmr28XE9Agx9E%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/process_info.json?sv=2019-07-07&sr=b&sig=cm4ZLkLyaqMhDdAnhxBG54eyYcsu1JWLlmvWrrMv4hk%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/azureml-logs/process_status.json?sv=2019-07-07&sr=b&sig=SL3xCxWiHTuc4O7ATRK4gwmI%2F9o1npbOAGvD1c%2Fxr5w%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'logs/azureml/97_azureml.log': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/logs/azureml/97_azureml.log?sv=2019-07-07&sr=b&sig=U4JPnytNUZ9F2fKb3bBukBfVIW2LoO3tIfQAc58xDrU%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/logs/azureml/job_prep_azureml.log?sv=2019-07-07&sr=b&sig=hlo13mdJykkHv72LUldapGpZQpoYICHFiEACo6KSJi0%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mlrgeastus4570506716.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635691878_4428a645/logs/azureml/job_release_azureml.log?sv=2019-07-07&sr=b&sig=ajE4AasghpIyyMXoWCrZFfBf0lRvsSqMk%2Bq2bQYQRXQ%3D&skoid=1784ea71-5d40-4bc7-a54c-9b7a0c19cc72&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-31T14%3A41%3A24Z&ske=2021-11-01T22%3A51%3A24Z&sks=b&skv=2019-07-07&st=2021-10-31T14%3A56%3A04Z&se=2021-10-31T23%3A06%3A04Z&sp=r'},
#  'submittedBy': 'Youjin'}

# %%
print(run.get_metrics())
# Out:
# {'Final test loss(mse)': 0.3835103484717282, 'Final test loss(mae)': 0.5201957821846008, 'loss VS val_loss': 'aml://artifactId/ExperimentRun/dcid.myExp_1635691878_4428a645/loss VS val_loss_1635692738.png'}

# %%
print(run.get_file_names())
# Out:
# ['azureml-logs/20_image_build_log.txt', 'azureml-logs/55_azureml-execution-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt', 'azureml-logs/65_job_prep-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt', 'azureml-logs/70_driver_log.txt', 'azureml-logs/75_job_post-tvmps_dd69fe3e4bc7905cd1242b8a0a4d0d11aed400dbf469bd081edc9fe3d1c72231_d.txt', 'azureml-logs/process_info.json', 'azureml-logs/process_status.json', 'logs/azureml/97_azureml.log', 'logs/azureml/job_prep_azureml.log', 'logs/azureml/job_release_azureml.log', 'loss VS val_loss_1635692738.png', 'outputs/Youjin_test_model.pkl']

# %%
'''model = run.register_model(model_name='myModelYoujin2', model_path='.')'''
# Out:
# "model = run.register_model(model_name='myModelYoujin2', model_path='.')"

# %%
from azureml.core import Model
from azureml.core.resource_configuration import ResourceConfiguration

model = run.register_model(model_name='Youjin-test', 
                           model_path='outputs/Youjin_test_model.pkl',
                           model_framework=Model.Framework.TENSORFLOW,
                           model_framework_version='2.0',
                           )

print(model.name, model.id, model.version, sep='\t')
# Out:
# Youjin-test	Youjin-test:1	1

# %%
'''os.makedirs('./model', exist_ok=True)

for f in run.get_file_names():
    if f.startswith('outputs/model'):
        output_file_path = os.path.join('./model', f.split('/')[-1])
        print('Downloading from {} to {} ...'.format(f, output_file_path))
        run.download_file(name=f, output_file_path=output_file_path)'''
# Out:
# "os.makedirs('./model', exist_ok=True)\n\nfor f in run.get_file_names():\n    if f.startswith('outputs/model'):\n        output_file_path = os.path.join('./model', f.split('/')[-1])\n        print('Downloading from {} to {} ...'.format(f, output_file_path))\n        run.download_file(name=f, output_file_path=output_file_path)"
