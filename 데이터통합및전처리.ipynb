# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mosquito_df = pd.read_csv('C:/Users/LG/Desktop/data.csv',encoding='UTF-8-sig')
mosquito_df
# Out:
#         ID        Date  Mean Temperature(°C)  Minimum Temperature(°C)  \
# 0        1  2021-09-27                  21.6                     18.7
# 1        2  2021-09-26                  22.6                     18.4
# 2        3  2021-09-25                  21.2                     18.7
# 3        4  2021-09-24                  21.8                     16.7
# 4        5  2021-09-23                  20.9                     16.9
# ...    ...         ...                   ...                      ...
# 1065  1066  2016-05-05                  18.9                     10.2
# 1066  1067  2016-05-04                  15.7                     10.2
# 1067  1068  2016-05-03                  12.9                      8.9
# 1068  1069  2016-05-02                  21.1                     16.5
# 1069  1070  2016-05-01                  18.8                     12.2
#
#       Maximum Temperature(°C)  Precipitation(mm)  Maximum wind speed(m/s)  \
# ...

# %%
mosquito_df = mosquito_df.dropna()# Null값 제거

# %%
mosquito_df= mosquito_df.drop(['ID'],axis='columns') # 필요없는 column제거

# %%
mosquito_df
# Out:
#             Date  Mean Temperature(°C)  Minimum Temperature(°C)  \
# 0     2021-09-27                  21.6                     18.7
# 1     2021-09-26                  22.6                     18.4
# 2     2021-09-25                  21.2                     18.7
# 3     2021-09-24                  21.8                     16.7
# 4     2021-09-23                  20.9                     16.9
# ...          ...                   ...                      ...
# 1065  2016-05-05                  18.9                     10.2
# 1066  2016-05-04                  15.7                     10.2
# 1067  2016-05-03                  12.9                      8.9
# 1068  2016-05-02                  21.1                     16.5
# 1069  2016-05-01                  18.8                     12.2
#
#       Maximum Temperature(°C)  Precipitation(mm)  Maximum wind speed(m/s)  \
# 0                        25.0                0.0                      6.6
# ...

# %%
mosquito_df.describe()
# Out:
#        Mean Temperature(°C)  Minimum Temperature(°C)  Maximum Temperature(°C)  \
# count           1038.000000              1038.000000              1038.000000
# mean              22.496821                18.538054                27.241522
# std                4.741259                 5.321513                 4.716000
# min                5.700000                 0.700000                 8.200000
# 25%               19.500000                14.900000                24.300000
# 50%               23.000000                19.100000                27.600000
# 75%               25.700000                22.600000                30.200000
# max               33.700000                30.300000                39.600000
#
#        Precipitation(mm)  Maximum wind speed(m/s)  Mean Wind Speed (m/s)  \
# count        1038.000000              1038.000000            1038.000000
# mean            5.405684                 8.165703               2.068882
# ...

# %%
mosquito_df.corrwith(mosquito_df['Mosquito Value'])
# Out:
# Mean Temperature(°C)             0.457187
# Minimum Temperature(°C)          0.509301
# Maximum Temperature(°C)          0.353309
# Precipitation(mm)                0.143756
# Maximum wind speed(m/s)          0.028199
# Mean Wind Speed (m/s)            0.108794
# Minimum Relative Humidity(%)     0.395072
# Mean Relative Humidity(%)        0.361955
# Duration of Sunshine(hr)        -0.248623
# Mean Surface Temperature(°C)     0.389461
# Minimum Grass Temperature(°C)    0.519614
# Cumulative Precipitation (mm)    0.233390
# Mosquito Value                   1.000000
# dtype: float64

# %%
mosquito_df = mosquito_df.drop(['Maximum wind speed(m/s)'],axis='columns') 
# 무의미한 상관관계 가지는 feature 삭제

# %%
mosquito_df.to_csv('C:/Users/LG/Desktop/result.csv')
