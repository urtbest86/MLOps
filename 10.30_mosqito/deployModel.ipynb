# %%
# %matplotlib inline
import numpy as np
import os

# %%
import azureml
from azureml.core import Workspace

# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.34.0

# %% [markdown]
# # Workspace 연결

# %%
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Workspace name: mlrgeastus
# Azure region: eastus
# Subscription id: 932c3e14-d0cf-4e41-9998-bdebb9bfa1cf
# Resource group: mlrg

# %% [markdown]
# # 실험 연결

# %%
from azureml.core import Experiment
experiment_name = 'myExp'

exp = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# ### 생성할 모델 코드 확인

# %%
script_folder = './'
os.makedirs(script_folder, exist_ok=True)

with open(os.path.join(script_folder, 'myModel.py'), 'r') as f:
    print(f.read())
# Out:
# import pandas as pd
# import numpy as np
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
#
#
#
# DATA_PATH="https://raw.githubusercontent.com/urtbest86/MLOps/master/result_train_dataset2.csv"
# df = pd.read_csv(DATA_PATH)
#
# DATA_PATH="https://raw.githubusercontent.com/urtbest86/MLOps/master/result_test_dataset2.csv"
# test = pd.read_csv(DATA_PATH)
#
# train=df.sample(frac=0.8)
# val=df.sample(frac=0.2)
#
# mean = train.mean(axis=0)
# train -= mean
# std = train.std(axis=0)
# train /= std
#
# test -= mean
# test /= std
#
# val-=mean
# val/=std
#
# train_data_set = train.values
# x_train = train_data_set[:, 2:-1].astype(float)
# y_train = train_data_set[:, -1].astype(float)
#
# test_data_set = test.values
# x_test = test_data_set[:, 2:-1].astype(float)
# y_test = test_data_set[:, -1].astype(float)
#
# val_data_set = val.values
# x_val = val_data_set[:, 2:-1].astype(float)
# y_val = val_data_set[:, -1].astype(float)
#
#
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
#
# model = Sequential()
# model.add(Dense(1024, input_dim = 4, activation='relu'))
# model.add(Dense(500,activation='relu'))
# model.add(Dense(300,activation='relu'))
# model.add(Dense(200,activation='relu'))
# model.add(Dense(1))
#
#
# rgs=model.compile(loss='mse', optimizer='adam',metrics=['mae'])
#
# eph_size=150
# hist=model.fit(x_train, y_train, epochs=eph_size, batch_size=4,validation_data=(x_val,y_val))
#
#
# laoss_nd_metrics = model.evaluate(x_test, y_test, batch_size=32)
#
#
#
# from azureml.core.run import Run
# # start an Azure ML run
# run = Run.get_context()
#
# # log a single value
# run.log("Final test loss(mse)", laoss_nd_metrics[0])
# print('Test loss(mse):', laoss_nd_metrics[0])
#
# run.log('Final test loss(mae)', laoss_nd_metrics[1])
# print('Test loss(mae):', laoss_nd_metrics[1])
#
#
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(6, 3))
# plt.title('Mosquito with Keras MLP ({} epochs)'.format(eph_size), fontsize=14)
# plt.plot(hist.history['loss'], 'b-', label='loss', lw=4, alpha=0.5)
# plt.plot(hist.history['val_loss'], 'r--', label='val_loss', lw=4, alpha=0.5)
# plt.legend(fontsize=12)
# plt.grid(True)
# plt.show()
# run.log_image('loss VS val_loss', plot=plt)
#
#
# import joblib
#
# os.makedirs('outputs', exist_ok=True)
# # note file saved in the outputs folder is automatically uploaded into experiment record
# joblib.dump(value=rgs, filename='outputs/Youjin_test_model.pkl')
#
#
#
# '''import matplotlib.pyplot as plt
#
# plt.plot(model.predict(x_test),label='predict value')
# plt.plot(y_test, label='real value')
# plt.plot(model.predict(x_test))
# plt.legend()
# plt.show()
#
#
# from azureml.core import Run
#
# run = Run.get_context()
#
# score = model.evaluate(x_test, y_test, verbose=0)
#
# run.log_image('Accuracy vs Loss', plot=plt)'''

# %% [markdown]
# # 기존 compute resource에 연결

# %%
'''from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
import os

compute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "test-cluster")

if compute_name in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
else:
    print("creating new compute target...")'''
# Out:
# 'from azureml.core.compute import AmlCompute\nfrom azureml.core.compute import ComputeTarget\nimport os\n\ncompute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "test-cluster")\n\nif compute_name in ws.compute_targets:\n    compute_target = ws.compute_targets[compute_name]\n    if compute_target and type(compute_target) is AmlCompute:\n        print("found compute target: " + compute_name)\nelse:\n    print("creating new compute target...")'

# %% [markdown]
# # compute resource 존재 확인 후 생성 또는 연결

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
import os

# choose a name for your cluster
compute_name = os.environ.get("AML_COMPUTE_CLUSTER_NAME", "cpu-cluster")
compute_min_nodes = os.environ.get("AML_COMPUTE_CLUSTER_MIN_NODES", 0)
compute_max_nodes = os.environ.get("AML_COMPUTE_CLUSTER_MAX_NODES", 4)

# This example uses CPU VM. For using GPU VM, set SKU to STANDARD_NC6
vm_size = os.environ.get("AML_COMPUTE_CLUSTER_SKU", "STANDARD_D11_V2")


if compute_name in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print("found compute target: " + compute_name)
else:
    print("creating new compute target...")
    provisioning_config = AmlCompute.provisioning_configuration(vm_size = vm_size,
                                                                min_nodes = compute_min_nodes, 
                                                                max_nodes = compute_max_nodes)

    # create the cluster
    compute_target = ComputeTarget.create(ws, compute_name, provisioning_config)
    
    # can poll for a minimum number of nodes and for a specific timeout. 
    # if no min node count is provided it will use the scale settings for the cluster
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
    
     # For a more detailed view of current AmlCompute status, use get_status()
    print(compute_target.get_status().serialize())
# Out:
# found compute target: cpu-cluster

# %% [markdown]
# # Workspace에 환경 등록

# %%
# %%writefile conda_dependencies.yml
#
# channels:
# - conda-forge
# dependencies:
# - python=3.6.2
#
# - pip:
#   - h5py<=2.10.0
#   - azureml-defaults
#   - tensorflow-gpu==2.0.0
#   - keras<=2.3.1
#   - matplotlib
#   - pandas
#   - scikit-learn
# Out:
# Overwriting conda_dependencies.yml

# %% [markdown]
# # 실험에 코드 실행 환경 등록

# %%
from azureml.core import Environment

env = Environment.from_conda_specification(name = 'keras-2.3.1', file_path = './conda_dependencies.yml')

'''# Specify a GPU base image
env.docker.enabled = True
env.docker.base_image = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu18.04'''

env.register(workspace = ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "keras-2.3.1",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "h5py<=2.10.0",
#                         "azureml-defaults",
#                         "tensorflow-gpu==2.0.0",
#                         "keras<=2.3.1",
#                         "matplotlib",
#                         "pandas",
#                         "scikit-learn"
#                     ]
#                 }
#             ],
#             "name": "azureml_a8a0845f249cc373e9e7168f4f641be5"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %% [markdown]
# # 학습 실행 구성 및 제출
# ### ScriptRunConfig 만들기

# %% [markdown]
# 모델에 대한 정보들 적어주기

# %%
from azureml.core import ScriptRunConfig

args = ['--data-folder', 
        '--batch-size', 4,
        '--first-layer-neurons', 1024,
        '--second-layer-neurons', 500,
        '--third-layer-neurons', 300,
        '--forth-layer-neurons', 200,
        '--learning-rate', 0.001]

src = ScriptRunConfig(source_directory=script_folder,
                      script='myModel.py',
                      arguments=args,
                      compute_target=compute_name,
                      environment=env)

# %%
run = exp.submit(src)

# %%
from azureml.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
run
# Out:
# Run(Experiment: myExp,
# Id: myExp_1635511217_f8661097,
# Type: azureml.scriptrun,
# Status: Starting)

# %% [markdown]
# 실행 상태를 모니터링 하고 필요에 따라 실행 로그를 스트리밍

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: myExp_1635511217_f8661097
# Web View: https://ml.azure.com/runs/myExp_1635511217_f8661097?wsid=/subscriptions/932c3e14-d0cf-4e41-9998-bdebb9bfa1cf/resourcegroups/mlrg/workspaces/mlrgeastus&tid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65
#
# Streaming azureml-logs/55_azureml-execution-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt
# ========================================================================================================================
#
# 2021-10-29T12:45:03Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635511217_f8661097/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635511217_f8661097/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=92214 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635511217_f8661097/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-29T12:45:04Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635511217_f8661097/mounts/workspaceblobstore
# 2021-10-29T12:45:04Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-29T12:45:04Z Starting output-watcher...
# 2021-10-29T12:45:04Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-29T12:45:06Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-10-29T12:45:06Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_dded69baa6f866c564c25bc60667a4a7
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 8d5d2c7721e5: Pulling fs layer
# edf39db86a87: Pulling fs layer
# 4e51411c197f: Pulling fs layer
# 527c4ceba3ec: Pulling fs layer
# e48f4b5a93cf: Pulling fs layer
# b1ef594c0b60: Pulling fs layer
# 2b9d5a91bfe2: Pulling fs layer
# 978e354c149e: Pulling fs layer
# 138058a08bc4: Pulling fs layer
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# 8d5d2c7721e5: Waiting
# edf39db86a87: Waiting
# 4e51411c197f: Waiting
# 527c4ceba3ec: Waiting
# e48f4b5a93cf: Waiting
# b1ef594c0b60: Waiting
# 2b9d5a91bfe2: Waiting
# 978e354c149e: Waiting
# 138058a08bc4: Waiting
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 8d5d2c7721e5: Verifying Checksum
# 8d5d2c7721e5: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# edf39db86a87: Verifying Checksum
# edf39db86a87: Download complete
# 4e51411c197f: Verifying Checksum
# 4e51411c197f: Download complete
# 527c4ceba3ec: Verifying Checksum
# 527c4ceba3ec: Download complete
# b1ef594c0b60: Verifying Checksum
# b1ef594c0b60: Download complete
# 2b9d5a91bfe2: Verifying Checksum
# 2b9d5a91bfe2: Download complete
# 138058a08bc4: Verifying Checksum
# 138058a08bc4: Download complete
# feac53061382: Pull complete
# 978e354c149e: Verifying Checksum
# 978e354c149e: Download complete
# e48f4b5a93cf: Verifying Checksum
# e48f4b5a93cf: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# 8d5d2c7721e5: Pull complete
# edf39db86a87: Pull complete
# 4e51411c197f: Pull complete
# 527c4ceba3ec: Pull complete
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/10/29 12:48:30 Got JobInfoJson from env
# 2021/10/29 12:48:30 Starting App Insight Logger for task:  runTaskLet
# 2021/10/29 12:48:30 Version: 3.0.01755.0003 Branch: .SourceBranch Commit: 66828d8
# 2021/10/29 12:48:30 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/10/29 12:48:30 Send process info logs to master server succeeded
# 2021/10/29 12:48:30 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/10/29 12:48:30 Send process info logs to master server succeeded
# [2021-10-29T12:48:30.677486] Entering context manager injector.
# [2021-10-29T12:48:31.361220] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['myModel.py', '--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001'])
# Script type = None
# [2021-10-29T12:48:31.365970] Entering Run History Context Manager.
# [2021-10-29T12:48:32.211289] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlrgeastus/azureml/myexp_1635511217_f8661097/wd/azureml/myExp_1635511217_f8661097
# [2021-10-29T12:48:32.211585] Preparing to call script [myModel.py] with arguments:['--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001']
# [2021-10-29T12:48:32.211622] After variable expansion, calling script [myModel.py] with arguments:['--data-folder', '--batch-size', '4', '--first-layer-neurons', '1024', '--second-layer-neurons', '500', '--third-layer-neurons', '300', '--forth-layer-neurons', '200', '--learning-rate', '0.001']
#
# 2021-10-29 12:48:34.436291: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib:
# 2021-10-29 12:48:34.436338: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-29 12:48:34.436367: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (4dc593b98f154af5878e320a564cfd5d000000): /proc/driver/nvidia/version does not exist
# 2021-10-29 12:48:34.436592: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-10-29 12:48:34.442750: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2397225000 Hz
# 2021-10-29 12:48:34.442965: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3bcbd70 executing computations on platform Host. Devices:
# 2021-10-29 12:48:34.442999: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 809 samples, validate on 202 samples
# Epoch 1/150
#
#   4/809 [..............................] - ETA: 3:08 - loss: 0.9853 - mae: 0.55712021/10/29 12:48:35 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#  40/809 [>.............................] - ETA: 19s - loss: 1.1130 - mae: 0.8204
#  76/809 [=>............................] - ETA: 10s - loss: 1.1044 - mae: 0.8341
# 112/809 [===>..........................] - ETA: 6s - loss: 1.0245 - mae: 0.8002
# 148/809 [====>.........................] - ETA: 5s - loss: 1.0398 - mae: 0.8178
# 184/809 [=====>........................] - ETA: 4s - loss: 0.9770 - mae: 0.7917
# 220/809 [=======>......................] - ETA: 3s - loss: 0.9213 - mae: 0.7703
# 260/809 [========>.....................] - ETA: 2s - loss: 0.8654 - mae: 0.7417
# 296/809 [=========>....................] - ETA: 2s - loss: 0.8318 - mae: 0.7254
# 332/809 [===========>..................] - ETA: 2s - loss: 0.7992 - mae: 0.7099
# 368/809 [============>.................] - ETA: 1s - loss: 0.7928 - mae: 0.7043
# 408/809 [==============>...............] - ETA: 1s - loss: 0.8027 - mae: 0.7065
# 440/809 [===============>..............] - ETA: 1s - loss: 0.7970 - mae: 0.7081
# 472/809 [================>.............] - ETA: 1s - loss: 0.7942 - mae: 0.7061
# 500/809 [=================>............] - ETA: 1s - loss: 0.7979 - mae: 0.7086
# 536/809 [==================>...........] - ETA: 0s - loss: 0.7890 - mae: 0.7056
# 564/809 [===================>..........] - ETA: 0s - loss: 0.7859 - mae: 0.7055
# 596/809 [=====================>........] - ETA: 0s - loss: 0.7819 - mae: 0.7062
# 628/809 [======================>.......] - ETA: 0s - loss: 0.7890 - mae: 0.7118
# 664/809 [=======================>......] - ETA: 0s - loss: 0.7850 - mae: 0.7098
# 704/809 [=========================>....] - ETA: 0s - loss: 0.7697 - mae: 0.6997
# 740/809 [==========================>...] - ETA: 0s - loss: 0.7646 - mae: 0.6963
# 784/809 [============================>.] - ETA: 0s - loss: 0.7409 - mae: 0.6848
# 809/809 [==============================] - 2s 3ms/sample - loss: 0.7377 - mae: 0.6836 - val_loss: 0.5510 - val_mae: 0.6017
# Epoch 2/150
#
#   4/809 [..............................] - ETA: 1s - loss: 1
# 809/809 [==============================] - 1s 2ms/sample - loss: 0.1993 - mae: 0.2997 - val_loss: 0.2534 - val_mae: 0.3383
# Epoch 108/150
#
#   4/809 [..............................] - ETA: 1s - loss: 0.1313 - mae: 0.2210
#  40/809 [>.............................] - ETA: 1s - loss: 0.2454 - mae: 0.3462
#  76/809 [=>............................] - ETA: 1s - loss: 0.2156 - mae: 0.3349
# 116/809 [===>..........................] - ETA: 1s - loss: 0.2009 - mae: 0.3185
# 152/809 [====>.........................] - ETA: 0s - loss: 0.2114 - mae: 0.3285
# 196/809 [======>.......................] - ETA: 0s - loss: 0.2277 - mae: 0.3259
# 236/809 [=======>......................] - ETA: 0s - loss: 0.2041 - mae: 0.3062
# 268/809 [========>.....................] - ETA: 0s - loss: 0.1978 - mae: 0.3043
# 308/809 [==========>...................] - ETA: 0s - loss: 0.1927 - mae: 0.3029
# 348/809 [===========>..................] - ETA: 0s - loss: 0.1979 - mae: 0.3071
# 392/809 [=============>................] - ETA: 0s - loss: 0.1902 - mae: 0.3019
# 428/809 [==============>...............] - ETA: 0s - loss: 0.2006 - mae: 0.3051
# 468/809 [================>.............] - ETA: 0s - loss: 0.2079 - mae: 0.3117
# 504/809 [=================>............] - ETA: 0s - loss: 0.2029 - mae: 0.3053
# 540/809 [===================>..........] - ETA: 0s - loss: 0.2003 - mae: 0.3039
# 580/809 [====================>.........] - ETA: 0s - loss: 0.2069 - mae: 0.3089
# 616/809 [=====================>........] - ETA: 0s - loss: 0.2091 - mae: 0.3124
# 652/809 [=======================>......] - ETA: 0s - loss: 0.2041 - mae: 0.3074
# 692/809 [========================>.....] - ETA: 0s - loss: 0.2021 - mae: 0.3044
# 728/809 [=========================>....] - ETA: 0s - loss: 0.2015 - mae: 0.3042
# 760/809 [===========================>..] - ETA: 0s - loss: 0.2031 - mae: 0.3056
# 796/809 [============================>.] - ETA: 0s - loss: 0.2092 - mae: 0.3111
# 809/809 [==============================] - 1s 2ms/sample - loss: 0.2125 - mae: 0.3134 - val_loss: 0.2492 - val_mae: 0.3302
# Epoch 109/150
#
#   4/809 [..............................] - ETA: 1s - loss: 0.0042 - mae: 0.0549
#  36/809 [>.............................] - ETA: 1s - loss: 0.1396 - mae: 0.2585
#  72/809 [=>............................] - ETA: 1s - loss: 0.1805 - mae: 0.3028
# 112/809 [===>..........................] - ETA: 1s - loss: 0.2133 - mae: 0.3372
# 152/809 [====>.........................] - ETA: 0s - loss: 0.1907 - mae: 0.3147
# 192/809 [======>.......................] - ETA: 0s - loss: 0.1852 - mae: 0.3126
# 232/809 [=======>......................] - ETA: 0s - loss: 0.1783 - mae: 0.3109
#
# Streaming azureml-logs/75_job_post-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_a8a0845f249cc373e9e7168f4f641be5/lib/libtinfo.so.5: no version information available (required by bash)
# [2021-10-29T12:51:47.017021] Entering job release
# [2021-10-29T12:51:48.191242] Starting job release
# [2021-10-29T12:51:48.191999] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 615
# [2021-10-29T12:51:48.201408] job release stage : upload_datastore starting...
# [2021-10-29T12:51:48.202562] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-29T12:51:48.203073] job release stage : copy_batchai_cached_logs starting...
# [2021-10-29T12:51:48.203404] job release stage : execute_job_release starting...
# [2021-10-29T12:51:48.204095] job release stage : copy_batchai_cached_logs completed...
# [2021-10-29T12:51:48.205561] Entering context manager injector.
# [2021-10-29T12:51:48.209030] job release stage : upload_datastore completed...
# [2021-10-29T12:51:48.327358] job release stage : send_run_telemetry starting...
# [2021-10-29T12:51:48.349748] get vm size and vm region successfully.
# [2021-10-29T12:51:48.368545] get compute meta data successfully.
# [2021-10-29T12:51:48.465724] job release stage : execute_job_release completed...
# [2021-10-29T12:51:48.677445] post artifact meta request successfully.
# [2021-10-29T12:51:48.771344] upload compute record artifact successfully.
# [2021-10-29T12:51:48.771452] job release stage : send_run_telemetry completed...
# [2021-10-29T12:51:48.771907] Job release is complete
#
# Execution Summary
# =================
# RunId: myExp_1635511217_f8661097
# Web View: https://ml.azure.com/runs/myExp_1635511217_f8661097?wsid=/subscriptions/932c3e14-d0cf-4e41-9998-bdebb9bfa1cf/resourcegroups/mlrg/workspaces/mlrgeastus&tid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65
# {'runId': 'myExp_1635511217_f8661097',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2021-10-29T12:45:00.170322Z',
#  'endTimeUtc': '2021-10-29T12:51:57.280365Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '8c6c1883-17ac-4464-a8eb-46ea9e0d6cd5',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'myModel.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-folder',
#    '--batch-size',
#    '4',
#    '--first-layer-neurons',
#    '1024',
#    '--second-layer-neurons',
#    '500',
#    '--third-layer-neurons',
#    '300',
#    '--forth-layer-neurons',
#    '200',
#    '--learning-rate',
#    '0.001'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'keras-2.3.1',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['h5py<=2.10.0',
#         'azureml-defaults',
#         'tensorflow-gpu==2.0.0',
#         'keras<=2.3.1',
#         'matplotlib',
#         'pandas',
#         'scikit-learn']}],
#      'name': 'azureml_a8a0845f249cc373e9e7168f4f641be5'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True}},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/55_azureml-execution-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt?sv=2019-07-07&sr=b&sig=u6J9dkCOIG2Ne%2FTBWUscFfc%2BCe31coHYLQLOcjxU%2FH0%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/65_job_prep-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt?sv=2019-07-07&sr=b&sig=L0%2BfogNtgMaEyNXqczx7TT7d%2FhK6Ir8oefVFPzwSUmw%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=qitQo7%2BqzOnB%2Bd49qIyaacMXnNutJlHvvbqqcb9RYmY%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/75_job_post-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt?sv=2019-07-07&sr=b&sig=uzC%2FxoHJcYuc9NHJ%2BuxsOAo19jaI%2Bjc4AQ%2BdKo6L8O4%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/process_info.json?sv=2019-07-07&sr=b&sig=BhtL8GuacMEo4r4RPaCtAm80YExzw7UHJZHDpLmTg8E%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/azureml-logs/process_status.json?sv=2019-07-07&sr=b&sig=zE8RE5QcLh9dOj7h3IG1OozBhHzBUY0hW8YQZi4J5%2B0%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'logs/azureml/95_azureml.log': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/logs/azureml/95_azureml.log?sv=2019-07-07&sr=b&sig=5OtiDzgNBBxLjEzZp9%2B0noy%2BZzf9poKHL71%2FYKopZxc%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/logs/azureml/job_prep_azureml.log?sv=2019-07-07&sr=b&sig=EL9WHlEkpepWG9crKQwI77cGXb%2FCsAoA5ttzMSzZafA%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mlrgeastus0116489920.blob.core.windows.net/azureml/ExperimentRun/dcid.myExp_1635511217_f8661097/logs/azureml/job_release_azureml.log?sv=2019-07-07&sr=b&sig=C7oz%2FI066Rd1v%2Blbf6DOtlqfBC0F7rB0Xmeyw2xeXek%3D&skoid=bf0a2e9c-b8fa-4bf0-be4c-a30bb5c90cd4&sktid=19411b3a-b7ca-48d9-a1e2-31694d0ccb65&skt=2021-10-29T05%3A53%3A04Z&ske=2021-10-30T14%3A03%3A04Z&sks=b&skv=2019-07-07&st=2021-10-29T12%3A41%3A52Z&se=2021-10-29T20%3A51%3A52Z&sp=r'},
#  'submittedBy': 'Youjin'}

# %%
print(run.get_metrics())
# Out:
# {'Final test loss(mse)': 0.43531535972248425, 'Final test loss(mae)': 0.542100727558136, 'loss VS val_loss': 'aml://artifactId/ExperimentRun/dcid.myExp_1635511217_f8661097/loss VS val_loss_1635511903.png'}

# %%
print(run.get_file_names())
# Out:
# ['azureml-logs/55_azureml-execution-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt', 'azureml-logs/65_job_prep-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt', 'azureml-logs/70_driver_log.txt', 'azureml-logs/75_job_post-tvmps_f6139ad5e074bbf39c7ea91106e2405916658dbba721f06a679f28360168d2b1_d.txt', 'azureml-logs/process_info.json', 'azureml-logs/process_status.json', 'logs/azureml/95_azureml.log', 'logs/azureml/job_prep_azureml.log', 'logs/azureml/job_release_azureml.log', 'loss VS val_loss_1635511903.png', 'outputs/Youjin_test_model.pkl']

# %% [markdown]
# # 생성된 모델 등록

# %%
'''model = run.register_model(model_name='myModelYoujin2', model_path='.')'''
# Out:
# "model = run.register_model(model_name='myModelYoujin2', model_path='.')"

# %%
from azureml.core import Model
from azureml.core.resource_configuration import ResourceConfiguration

model = run.register_model(model_name='Youjin-test', 
                           model_path='outputs/Youjin_test_model.pkl',
                           model_framework=Model.Framework.TENSORFLOW,
                           model_framework_version='2.0',
                           )

print(model.name, model.id, model.version, sep='\t')
# Out:
# Youjin-test	Youjin-test:3	3

# %%
'''os.makedirs('./model', exist_ok=True)

for f in run.get_file_names():
    if f.startswith('outputs/model'):
        output_file_path = os.path.join('./model', f.split('/')[-1])
        print('Downloading from {} to {} ...'.format(f, output_file_path))
        run.download_file(name=f, output_file_path=output_file_path)'''
# Out:
# "os.makedirs('./model', exist_ok=True)\n\nfor f in run.get_file_names():\n    if f.startswith('outputs/model'):\n        output_file_path = os.path.join('./model', f.split('/')[-1])\n        print('Downloading from {} to {} ...'.format(f, output_file_path))\n        run.download_file(name=f, output_file_path=output_file_path)"
